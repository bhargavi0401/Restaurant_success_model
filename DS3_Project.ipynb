# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
import json
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
jsonList_bus=[]

with open('yelp_training_set_business.json','r') as file:
    
    for f in file:
        x=json.loads(f)
        jsonList_bus.append(x)

# %%
#Converting data from JSON to CSV
with open('yelp_training_set_business.csv', 'w', newline='', encoding='utf-8') as csv_file:
    csv_writer = csv.writer(csv_file)
    count = 0
 
    for emp in jsonList_bus:
            if count == 0:
 
        # Writing headers of CSV file
                header = emp.keys()
                csv_writer.writerow(header)
                count += 1
 
    # Writing data of CSV file
            csv_writer.writerow(emp.values())

# %%
df_bus=pd.read_csv("yelp_training_set_business.csv")

# %%
df_bus
# Out:
#                   business_id  \
# 0      rncjoVoEFUJGCUoC1JgnUA
# 1      0FNFSzCFP_rGUoJx8W7tJg
# 2      3f_lyB6vFK48ukH6ScvLHg
# 3      usAsSV36QmUej8--yvN-dg
# 4      PzOqRohWw7F7YEPBz6AubA
# ...                       ...
# 11532  TCIVUf1frqLehZbaUnuQzQ
# 11533  F3tqTcfKnljJcSyyqN0bbw
# 11534  diW9KhKuhBCblBdnAkUkpQ
# 11535  tQTqlMW0sODNbe188ah1Yg
# 11536  6yVe_iet5qD7SzVMhRYYog
#
#                                             full_address  open  \
# 0             8466 W Peoria Ave\nSte 6\nPeoria, AZ 85345  True
# 1                      2149 W Wood Dr\nPhoenix, AZ 85029  True
# 2                  1134 N Central Ave\nPhoenix, AZ 85004  True
# 3                  845 W Southern Ave\nPhoenix, AZ 85041  True
# 4      6520 W Happy Valley Rd\nSte 101\nGlendale Az, ...  True
# ...                                                  ...   ...
# 11532     1158 W Washington St\nSte 101\nTempe, AZ 85281  True
# 11533           8489 E McDonald Dr\nScottsdale, AZ 85250  True
# ...

# %%
jsonList_chk=[]

with open('yelp_training_set_checkin.json','r') as file:
    
    for f in file:
        x=json.loads(f)
        jsonList_chk.append(x)
        
with open('yelp_training_set_checkin.csv', 'w', newline='', encoding='utf-8') as csv_file:
    csv_writer = csv.writer(csv_file)
    count = 0
 
    for emp in jsonList_chk:
            if count == 0:
 
        # Writing headers of CSV file
                header = emp.keys()
                csv_writer.writerow(header)
                count += 1
 
    # Writing data of CSV file
            csv_writer.writerow(emp.values())

        
        
df_chk=pd.read_csv("yelp_training_set_checkin.csv")

# %%
df_chk
# Out:
#                                            checkin_info     type  \
# 0     {'11-3': 17, '8-5': 1, '15-0': 2, '15-3': 2, '...  checkin
# 1     {'0-5': 1, '2-6': 2, '2-5': 3, '3-6': 1, '3-5'...  checkin
# 2     {'13-4': 1, '7-4': 1, '15-3': 1, '18-5': 1, '2...  checkin
# 3     {'13-5': 1, '17-6': 1, '15-1': 1, '20-0': 1, '...  checkin
# 4     {'16-2': 1, '14-5': 1, '12-5': 2, '15-4': 1, '...  checkin
# ...                                                 ...      ...
# 8277  {'19-4': 1, '13-4': 1, '11-5': 1, '17-2': 1, '...  checkin
# 8278  {'5-0': 1, '7-3': 2, '7-2': 1, '7-1': 1, '7-0'...  checkin
# 8279  {'15-0': 1, '15-2': 1, '15-5': 1, '15-6': 1, '...  checkin
# 8280  {'22-6': 4, '22-5': 20, '22-4': 17, '22-3': 11...  checkin
# 8281  {'16-1': 1, '16-3': 2, '15-1': 1, '15-0': 1, '...  checkin
#
#                  business_id
# 0     KO9CpaSPOoqm0iCWm5scmg
# 1     oRqBAYtcBYZHXA7G8FlPaA
# 2     6cy2C9aBXUwkrh4bY1DApw
# 3     D0IB17N66FiyYDCzTlAI4A
# 4     HLQGo3EaYVvAv22bONGkIw
# ...

# %%
jsonList_rev=[]

with open('yelp_training_set_review.json','r') as file:
    
    for f in file:
        x=json.loads(f)
        jsonList_rev.append(x)
        
with open('yelp_training_set_review.csv', 'w', newline='', encoding='utf-8') as csv_file:
    csv_writer = csv.writer(csv_file)
    count = 0
 
    for emp in jsonList_rev:
            if count == 0:
 
        # Writing headers of CSV file
                header = emp.keys()
                csv_writer.writerow(header)
                count += 1
 
    # Writing data of CSV file
            csv_writer.writerow(emp.values())

        
        
df_rev=pd.read_csv("yelp_training_set_review.csv")

# %%
df_rev
# Out:
#                                        votes                 user_id  \
# 0       {'funny': 0, 'useful': 5, 'cool': 2}  rLtl8ZkDX5vH5nAx9C3q5Q
# 1       {'funny': 0, 'useful': 0, 'cool': 0}  0a2KyEL0d3Yb1V6aivbIuQ
# 2       {'funny': 0, 'useful': 1, 'cool': 0}  0hT2KtfLiobPvh6cDC8JQg
# 3       {'funny': 0, 'useful': 2, 'cool': 1}  uZetl9T0NcROGOyFfughhg
# 4       {'funny': 0, 'useful': 0, 'cool': 0}  vYmM4KTsC8ZfQBg-j5MWkw
# ...                                      ...                     ...
# 229902  {'funny': 0, 'useful': 0, 'cool': 0}  6e7pZofhDuIlD_rX2oYirQ
# 229903  {'funny': 0, 'useful': 2, 'cool': 0}  dDNfSFT0VApxPmURclX6_g
# 229904  {'funny': 0, 'useful': 0, 'cool': 0}  M5wHt6Odh1k5v0tIjqd8DQ
# 229905  {'funny': 1, 'useful': 2, 'cool': 0}  jopndPrv-H5KW2CfScnw9A
# 229906  {'funny': 1, 'useful': 0, 'cool': 1}  mbRUG6h0Mgb2XIJvscIoMg
#
#                      review_id  stars        date  \
# 0       fWKvX83p0-ka4JS3dc6E5A      5  2011-01-26
# ...

# %% [raw]
# vote = df_rev["votes"]
# vote
# fun = []
# use = []
# _cool = []

# %%
import ast
vote = df_rev["votes"]
vote
fun = []
use = []
_cool = []
for i in vote:
    dic = ast.literal_eval(i)
    fun.append(dic["funny"])
    use.append(dic["useful"])
    _cool.append(dic["cool"])
df_rev["funny"] = fun
df_rev["useful"] = use
df_rev["cool"] = _cool
df_rev
# Out:
#                                        votes                 user_id  \
# 0       {'funny': 0, 'useful': 5, 'cool': 2}  rLtl8ZkDX5vH5nAx9C3q5Q
# 1       {'funny': 0, 'useful': 0, 'cool': 0}  0a2KyEL0d3Yb1V6aivbIuQ
# 2       {'funny': 0, 'useful': 1, 'cool': 0}  0hT2KtfLiobPvh6cDC8JQg
# 3       {'funny': 0, 'useful': 2, 'cool': 1}  uZetl9T0NcROGOyFfughhg
# 4       {'funny': 0, 'useful': 0, 'cool': 0}  vYmM4KTsC8ZfQBg-j5MWkw
# ...                                      ...                     ...
# 229902  {'funny': 0, 'useful': 0, 'cool': 0}  6e7pZofhDuIlD_rX2oYirQ
# 229903  {'funny': 0, 'useful': 2, 'cool': 0}  dDNfSFT0VApxPmURclX6_g
# 229904  {'funny': 0, 'useful': 0, 'cool': 0}  M5wHt6Odh1k5v0tIjqd8DQ
# 229905  {'funny': 1, 'useful': 2, 'cool': 0}  jopndPrv-H5KW2CfScnw9A
# 229906  {'funny': 1, 'useful': 0, 'cool': 1}  mbRUG6h0Mgb2XIJvscIoMg
#
#                      review_id  stars        date  \
# 0       fWKvX83p0-ka4JS3dc6E5A      5  2011-01-26
# ...

# %%
jsonList_usr=[]

with open('yelp_training_set_user.json','r') as file:
    
    for f in file:
        x=json.loads(f)
        jsonList_usr.append(x)
        
with open('yelp_training_set_user.csv', 'w', newline='', encoding='utf-8') as csv_file:
    csv_writer = csv.writer(csv_file)
    count = 0
 
    for emp in jsonList_usr:
            if count == 0:
 
        # Writing headers of CSV file
                header = emp.keys()
                csv_writer.writerow(header)
                count += 1
 
    # Writing data of CSV file
            csv_writer.writerow(emp.values())

        
        
df_usr=pd.read_csv("yelp_training_set_user.csv")

# %%
df_usr
# Out:
#                                           votes                 user_id  \
# 0          {'funny': 0, 'useful': 7, 'cool': 0}  CR2y7yEm4X035ZMzrTtN9Q
# 1          {'funny': 0, 'useful': 1, 'cool': 0}  _9GXoHhdxc30ujPaQwh6Ew
# 2          {'funny': 0, 'useful': 1, 'cool': 0}  8mM-nqxjg6pT04kwcjMbsw
# 3          {'funny': 0, 'useful': 2, 'cool': 0}  Ch6CdTR2IVaVANr-RglMOg
# 4          {'funny': 0, 'useful': 0, 'cool': 0}  NZrLmHRyiHmyT1JrfzkCOA
# ...                                         ...                     ...
# 43868  {'funny': 72, 'useful': 117, 'cool': 47}  SG56r_eAdyK9aad9H8dT4g
# 43869      {'funny': 2, 'useful': 6, 'cool': 3}  brlWQgZoM0_rF3QmmrA99g
# 43870      {'funny': 0, 'useful': 0, 'cool': 0}  bbGCiK43lyi6oqLGNHLMaQ
# 43871      {'funny': 3, 'useful': 5, 'cool': 6}  -iUnAEpltJi0MCjmWrPu9w
# 43872      {'funny': 1, 'useful': 4, 'cool': 2}  aTofoitZDS2l_DoYrmQomA
#
#             name  average_stars  review_count  type
# ...

# %%
df_bus.columns
# Out:
# Index(['business_id', 'full_address', 'open', 'categories', 'city',
#        'review_count', 'name', 'neighborhoods', 'longitude', 'state', 'stars',
#        'latitude', 'type'],
#       dtype='object')

# %%
df_chk.columns
# Out:
# Index(['checkin_info', 'type', 'business_id'], dtype='object')

# %%
df_rev.columns
# Out:
# Index(['votes', 'user_id', 'review_id', 'stars', 'date', 'text', 'type',
#        'business_id', 'funny', 'useful', 'cool'],
#       dtype='object')

# %%
df_usr.columns
# Out:
# Index(['votes', 'user_id', 'name', 'average_stars', 'review_count', 'type'], dtype='object')

# %%
len(df_bus[df_bus['open']==False])/len(df_bus)
# Out:
# 0.10609343850221029

# %%
plt.hist([df_bus[df_bus['open']==True].dropna()['stars'].values,\
          df_bus[df_bus['open']==False].dropna()['stars'].values],\
        label=['Open','Closed'],color=['k','#c41200'])


plt.legend()
plt.title('Yelp Stars Histogram',fontsize=14)
plt.xlabel('Yelp Star Rating',fontsize=14)
plt.ylabel('Total Number of Restaurants',fontsize=16)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.hist([df_bus[df_bus['open']==True].dropna()['review_count'].values,\
          df_bus[df_bus['open']==False].dropna()['review_count'].values],\
        label=['Open','Closed'],color=['k','#c41200'],log=True)



plt.legend()
plt.title('Number of Reviews Histogram')
plt.xlabel('Total Number of Reviews')
# Out:
# Text(0.5, 28.902777777777764, 'Total Number of Reviews')

# %%
std_str=[]
median_str=[]
avg_str=[]
for i in df_bus['business_id']:
    a=df_rev.query(f'business_id == "{i}"')
    median_str.append(a['stars'].median())
    std_str.append(a['stars'].std())
    avg_str.append(a['stars'].mean())

# %%
funny_l=[]
useful_l=[]
cool_l=[]
for i in df_bus['business_id']:
    abc=df_rev.query(f'business_id == "{i}"')
    funny_l.append(abc['funny'].mean())
    useful_l.append(abc['useful'].mean())
    cool_l.append(abc['cool'].mean())

# %%
df_n = df_bus.assign(new_col = median_str)
df_n.rename(columns={"new_col": "median_star"}, inplace=True)
df_n1=df_n.assign(new_col = std_str)
df_n1.rename(columns={"new_col": "std_star"}, inplace=True)
df_new=df_n1.assign(new_col = avg_str)
df_new.rename(columns={"new_col": "mean_star"}, inplace=True)

df_new["funny_m"] = funny_l
df_new["useful_m"] = useful_l
df_new["cool_m"] = cool_l

# %%
df_new
# Out:
#                   business_id  \
# 0      rncjoVoEFUJGCUoC1JgnUA
# 1      0FNFSzCFP_rGUoJx8W7tJg
# 2      3f_lyB6vFK48ukH6ScvLHg
# 3      usAsSV36QmUej8--yvN-dg
# 4      PzOqRohWw7F7YEPBz6AubA
# ...                       ...
# 11532  TCIVUf1frqLehZbaUnuQzQ
# 11533  F3tqTcfKnljJcSyyqN0bbw
# 11534  diW9KhKuhBCblBdnAkUkpQ
# 11535  tQTqlMW0sODNbe188ah1Yg
# 11536  6yVe_iet5qD7SzVMhRYYog
#
#                                             full_address  open  \
# 0             8466 W Peoria Ave\nSte 6\nPeoria, AZ 85345  True
# 1                      2149 W Wood Dr\nPhoenix, AZ 85029  True
# 2                  1134 N Central Ave\nPhoenix, AZ 85004  True
# 3                  845 W Southern Ave\nPhoenix, AZ 85041  True
# 4      6520 W Happy Valley Rd\nSte 101\nGlendale Az, ...  True
# ...                                                  ...   ...
# 11532     1158 W Washington St\nSte 101\nTempe, AZ 85281  True
# 11533           8489 E McDonald Dr\nScottsdale, AZ 85250  True
# ...

# %%
df_ml=df_new[['business_id','review_count','stars','std_star','median_star','open','mean_star','funny_m','useful_m','cool_m']]

# %%
df_ml
# Out:
#                   business_id  review_count  stars  std_star  median_star  \
# 0      rncjoVoEFUJGCUoC1JgnUA             3    5.0  0.000000          5.0
# 1      0FNFSzCFP_rGUoJx8W7tJg             5    5.0  0.000000          5.0
# 2      3f_lyB6vFK48ukH6ScvLHg             4    5.0  0.000000          5.0
# 3      usAsSV36QmUej8--yvN-dg             5    3.5  0.547723          3.0
# 4      PzOqRohWw7F7YEPBz6AubA            14    3.5  1.325987          4.0
# ...                       ...           ...    ...       ...          ...
# 11532  TCIVUf1frqLehZbaUnuQzQ            18    3.0  1.278275          3.0
# 11533  F3tqTcfKnljJcSyyqN0bbw            25    3.5  1.150362          4.0
# 11534  diW9KhKuhBCblBdnAkUkpQ             3    4.5  0.577350          4.0
# 11535  tQTqlMW0sODNbe188ah1Yg            23    3.5  1.121123          4.0
# 11536  6yVe_iet5qD7SzVMhRYYog            11    2.5  1.348400          2.0
#
#        open  mean_star   funny_m  useful_m    cool_m
# ...

# %%
len(df_ml)
# Out:
# 11537

# %%
df_ml_clean = df_ml.dropna(axis = 0)

# %%
len(df_ml_clean)
# Out:
# 11537

# %%
df_open = df_ml_clean[df_ml_clean['open'] == True]
df_close= df_ml_clean[df_ml_clean['open'] == False]

# %%
df_open
# Out:
#                   business_id  review_count  stars  std_star  median_star  \
# 0      rncjoVoEFUJGCUoC1JgnUA             3    5.0  0.000000          5.0
# 1      0FNFSzCFP_rGUoJx8W7tJg             5    5.0  0.000000          5.0
# 2      3f_lyB6vFK48ukH6ScvLHg             4    5.0  0.000000          5.0
# 3      usAsSV36QmUej8--yvN-dg             5    3.5  0.547723          3.0
# 4      PzOqRohWw7F7YEPBz6AubA            14    3.5  1.325987          4.0
# ...                       ...           ...    ...       ...          ...
# 11532  TCIVUf1frqLehZbaUnuQzQ            18    3.0  1.278275          3.0
# 11533  F3tqTcfKnljJcSyyqN0bbw            25    3.5  1.150362          4.0
# 11534  diW9KhKuhBCblBdnAkUkpQ             3    4.5  0.577350          4.0
# 11535  tQTqlMW0sODNbe188ah1Yg            23    3.5  1.121123          4.0
# 11536  6yVe_iet5qD7SzVMhRYYog            11    2.5  1.348400          2.0
#
#        open  mean_star   funny_m  useful_m    cool_m
# ...

# %%
print(len(df_open))
print(len(df_close))
# Out:
# 10313
# 1224

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_curve
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_graphviz
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
# Split in features and target
df_ml_features = df_ml_clean.drop('open',axis = 1)
df_ml_target = df_ml_clean['open']

# %%
# Split the entire dataset
df_train, df_test = train_test_split(df_ml_clean, test_size=0.2, random_state=10)

# Filter open and close businesses
df_open_train = df_train[df_train['open'] == True]
df_close_train = df_train[df_train['open'] == False]
df_open_test = df_test[df_test['open'] == True]
df_close_test = df_test[df_test['open'] == False]

# %%
len(df_open_train)
len(df_close_train)
# Out:
# 972

# %%
open_train_class = open_train["open"]
open_test_class = open_test["open"]
close_train_class = close_train["open"]
close_test_class = close_test["open"]

# %%
# Separate features and target
X_open_train = df_open_train.drop('open', axis=1)
y_open_train = df_open_train['open']
X_close_train = df_close_train.drop('open', axis=1)
y_close_train = df_close_train['open']


X_open_test = df_open_test.drop('open', axis=1)
y_open_test = df_open_test['open']
X_close_test = df_close_test.drop('open', axis=1)
y_close_test = df_close_test['open']

# %%
# Combine training and testing data for model training
X_train = pd.concat([X_open_train, X_close_train])
y_train = pd.concat([y_open_train, y_close_train])

X_test = pd.concat([X_open_test, X_close_test])
y_test = pd.concat([y_open_test, y_close_test])

# %%
# Remove 'business_id' column
X_train = X_train.drop('business_id', axis=1)
X_test = X_test.drop('business_id', axis=1)

# %%
df_ml=df_new[['business_id','review_count','stars','mean_star','funny_m','useful_m','cool_m']]

# %%
clf = LogisticRegression(random_state=0)
clf_A = GaussianNB()
clf_B = DecisionTreeClassifier(random_state=1)
clf_C = GradientBoostingClassifier(random_state=1)
clf_D = RandomForestClassifier(random_state=1)

# %%
# Logistic Regression Model
clf = LogisticRegression(random_state=0)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
print('Logistic Regression Model:')
print('Accuracy:', clf.score(X_test, y_test))
print('Precision:', precision_score(y_test, y_pred))
print('Recall:', recall_score(y_test, y_pred))
print('F1 Score:', f1_score(y_test, y_pred))
print('Confusion Matrix:\n', confusion_matrix(y_test, y_pred))
# Out:
# Logistic Regression Model:
# Accuracy: 0.8882149046793761
# Precision: 0.8912097476066144
# Recall: 0.9961089494163424
# F1 Score: 0.9407441433164906
# Confusion Matrix:
#  [[   2  250]
#  [   8 2048]]
# C:\Users\BHARGAVI\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
# Other Models (clf_A, clf_B, clf_C, clf_D) can be similarly trained and evaluated

# Example for GaussianNB (clf_A)
clf_A = GaussianNB()
clf_A.fit(X_train, y_train)
y_pred_A = clf_A.predict(X_test)
print('\nGaussianNB Model:')
print('Accuracy:', clf_A.score(X_test, y_test))
print('Precision:', precision_score(y_test, y_pred_A))
print('Recall:', recall_score(y_test, y_pred_A))
print('F1 Score:', f1_score(y_test, y_pred_A))
print('Confusion Matrix:\n', confusion_matrix(y_test, y_pred_A))
# Out:
# GaussianNB Model:
# Accuracy: 0.8509532062391681
# Precision: 0.8981395348837209
# Recall: 0.9392023346303502
# F1 Score: 0.9182120779838326
# Confusion Matrix:
#  [[  33  219]
#  [ 125 1931]]

# %%
# Decision Tree Classifier (clf_B)
clf_B = DecisionTreeClassifier(random_state=1)
clf_B.fit(X_train, y_train)
y_pred_B = clf_B.predict(X_test)

print('\nDecision Tree Classifier (clf_B):')
print('Accuracy:', clf_B.score(X_test, y_test))
print('Precision:', precision_score(y_test, y_pred_B))
print('Recall:', recall_score(y_test, y_pred_B))
print('F1 Score:', f1_score(y_test, y_pred_B))
print('Confusion Matrix:\n', confusion_matrix(y_test, y_pred_B))
# Out:
# Decision Tree Classifier (clf_B):
# Accuracy: 0.8232235701906413
# Precision: 0.9047151277013753
# Recall: 0.8959143968871596
# F1 Score: 0.9002932551319649
# Confusion Matrix:
#  [[  58  194]
#  [ 214 1842]]

# %%
# Gradient Boosting Classifier (clf_C)
clf_C = GradientBoostingClassifier(random_state=1)
clf_C.fit(X_train, y_train)
y_pred_C = clf_C.predict(X_test)

print('\nGradient Boosting Classifier (clf_C):')
print('Accuracy:', clf_C.score(X_test, y_test))
print('Precision:', precision_score(y_test, y_pred_C))
print('Recall:', recall_score(y_test, y_pred_C))
print('F1 Score:', f1_score(y_test, y_pred_C))
print('Confusion Matrix:\n', confusion_matrix(y_test, y_pred_C))
# Out:
# Gradient Boosting Classifier (clf_C):
# Accuracy: 0.891681109185442
# Precision: 0.8915871639202082
# Recall: 1.0
# F1 Score: 0.9426868408986704
# Confusion Matrix:
#  [[   2  250]
#  [   0 2056]]

# %%
# Random Forest Classifier (clf_D)
clf_D = RandomForestClassifier(random_state=1)
clf_D.fit(X_train, y_train)
y_pred_D = clf_D.predict(X_test)

print('\nRandom Forest Classifier (clf_D):')
print('Accuracy:', clf_D.score(X_test, y_test))
print('Precision:', precision_score(y_test, y_pred_D))
print('Recall:', recall_score(y_test, y_pred_D))
print('F1 Score:', f1_score(y_test, y_pred_D))
print('Confusion Matrix:\n', confusion_matrix(y_test, y_pred_D))
# Out:
# Random Forest Classifier (clf_D):
# Accuracy: 0.8851819757365684
# Precision: 0.8932806324110671
# Recall: 0.9892996108949417
# F1 Score: 0.9388414493422571
# Confusion Matrix:
#  [[   9  243]
#  [  22 2034]]

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# Get decision functions or predicted probabilities for each classifier
y_score = clf.decision_function(X_test)
y_score_A = clf_A.predict_proba(X_test)[:, 1]
y_score_B = clf_B.predict_proba(X_test)[:, 1]
y_score_C = clf_C.decision_function(X_test)
y_score_D = clf_D.predict_proba(X_test)[:, 1]

# Compute ROC curve and ROC area for each classifier
fpr, tpr, _ = roc_curve(y_test.values, y_score)
roc_auc = auc(fpr, tpr)

fpr_A, tpr_A, _ = roc_curve(y_test.values, y_score_A)
roc_auc_A = auc(fpr_A, tpr_A)

fpr_B, tpr_B, _ = roc_curve(y_test.values, y_score_B)
roc_auc_B = auc(fpr_B, tpr_B)

fpr_C, tpr_C, _ = roc_curve(y_test.values, y_score_C)
roc_auc_C = auc(fpr_C, tpr_C)

fpr_D, tpr_D, _ = roc_curve(y_test.values, y_score_D)
roc_auc_D = auc(fpr_D, tpr_D)

# Plot ROC curves
plt.figure(figsize=(8, 6))
plt.plot([0, 1], [0, 1], 'k--', label='Random')

plt.plot(fpr, tpr, label=f'Logistic Regression (AUC = {roc_auc:.2f})')
plt.plot(fpr_A, tpr_A, label=f'Gaussian NB (AUC = {roc_auc_A:.2f})')
plt.plot(fpr_B, tpr_B, label=f'Decision Tree (AUC = {roc_auc_B:.2f})')
plt.plot(fpr_C, tpr_C, label=f'Gradient Boosting (AUC = {roc_auc_C:.2f})')
plt.plot(fpr_D, tpr_D, label=f'Random Forest (AUC = {roc_auc_D:.2f})')

plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.title('Receiver Operating Characteristic (ROC) Curves')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
fpr, tpr, _ = roc_curve(y_test.values,y_score)
fpr_C, tpr_C, _ = roc_curve(y_test.values,y_score_C)

plt.plot([0,1],[0,1],'k--')

plt.plot(fpr,tpr,label='Logistic Regression')

plt.plot(fpr_C,tpr_C,label='Gradient Boosting')


plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.title('ROC Curves')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()
plt.show()

# %%
df_ml_features.columns
# Out:
# Index(['business_id', 'review_count', 'stars', 'std_star', 'median_star',
#        'mean_star', 'funny_m', 'useful_m', 'cool_m'],
#       dtype='object')

# %%
labels = ['Review Count','Star Rating','Std of Star Rating','Median of Star Rating','mean of star','funny vote','useful vote','cool vote']
len(labels)
# Out:
# 8

# %%
# Gradient Boosting importances
importances2 = clf_C.feature_importances_
#std2 = np.std([tree.feature_importances_ for tree in clf_C.estimators_],axis=0)
indices2 = np.argsort(importances2)[::-1]
# Print the feature ranking
print("Feature ranking:")

for f in range(X_test.shape[1]):
    print("%d. feature: %s (%f)" % (f + 1, df_ml_features.iloc[:,indices2[f]].name, importances2[indices2[f]]))
    #print("%d. feature: %s (%f)" % (f + 1, df_ml_features.columns[indices[f]], importances[indices[f]]))
# Out:
# Feature ranking:
# 1. feature: useful_m (0.405260)
# 2. feature: median_star (0.172690)
# 3. feature: mean_star (0.138742)
# 4. feature: business_id (0.101038)
# 5. feature: funny_m (0.072891)
# 6. feature: stars (0.068848)
# 7. feature: std_star (0.036209)
# 8. feature: review_count (0.004323)

# %%
# Gradient boosting
# %matplotlib inline
plt.figure(figsize=(10,7))
plt.title("Feature importance")
plt.barh(range(X_test.shape[1]), importances2[indices2],
       color="#c41200", align="center")
#plt.yticks(range(X_test.shape[1]), df_ml_features.iloc[:,indices].columns)
plt.yticks(range(X_test.shape[1]), [labels[i] for i in indices2])
plt.ylim([-1, X_test.shape[1]])
# Out:
# (-1.0, 8.0)
